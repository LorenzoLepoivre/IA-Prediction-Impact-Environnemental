# %% [markdown]
# # IA de prédiction de l'impact environnemental
# Cette IA à pour but de prédir l'impact sur le changement climatique (CO2 équivalent) d'un produit alimentaire.

# %% [markdown]
# # Exemple de base

# %% [markdown]
# ## Import

# %%
# Manipulation de données
import pandas as pd
import numpy as np

# Visualisation
import matplotlib.pyplot as plt
import seaborn as sns

# Machine learning - modèles
from sklearn.linear_model import LinearRegression, Ridge, Lasso, ElasticNet
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor

# Prétraitement
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.compose import ColumnTransformer, make_column_selector, make_column_transformer
from sklearn.pipeline import Pipeline
from sklearn.pipeline import make_pipeline
from sklearn.impute import SimpleImputer

# Évaluation
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error, r2_score, mean_squared_error
from sklearn.feature_selection import f_regression
from sklearn.model_selection import learning_curve
from sklearn.preprocessing import LabelEncoder

# %% [markdown]
# ## Data d'entraînement
# Les données pour entraîner le modèle proviennent de l'ADEME et sont disponibles [à cette adresse](https://www.data.gouv.fr/datasets/agribalyse-3-1-synthese/).

# %%
df = pd.read_csv("agribalyse_data.csv", sep=",")
# Aperçu
df.head()
# Out:
#   Code AGB  Code CIQUAL                        Groupe d'aliment  \
# 0    11172      11172.0  aides culinaires et ingrédients divers
# 1    25525      25525.0  aides culinaires et ingrédients divers
# 2    11214      11214.0  aides culinaires et ingrédients divers
# 3    11084      11084.0  aides culinaires et ingrédients divers
# 4    20995      20995.0  aides culinaires et ingrédients divers
#
#   Sous-groupe d'aliment                         Nom du Produit en Français  \
# 0      aides culinaires           Court-bouillon pour poissons, déshydraté
# 1      aides culinaires                        Pizza, sauce garniture pour
# 2      aides culinaires  Préparation culinaire à base de soja, type "cr...
# 3                algues                                  Agar (algue), cru
# 4                algues  Ao-nori (Enteromorpha sp.), séchée ou déshydratée
#
#                                             LCI Name  code saison  code avion  \
# 0          Aromatic stock cube, for fish, dehydrated          2.0         0.0
# 1                            Topping sauce for pizza          2.0         0.0
# 2                            Soy "cream" preparation          2.0         0.0
# 3                                 Seaweed, agar, raw          2.0         0.0
# 4  Sea lettuce (Enteromorpha sp.), dried or dehyd...          2.0         0.0
#
#         Livraison Approche emballage   ... Eutrophisation marine  \
# 0  Ambiant (long)          PACK PROXY  ...               0.02680
# 1  Ambiant (long)          PACK PROXY  ...               0.00416
# 2  Ambiant (long)          PACK PROXY  ...               0.00723
# 3  Ambiant (long)          PACK PROXY  ...               0.01500
# 4  Ambiant (long)          PACK PROXY  ...               0.01500
#
#    Eutrophisation terrestre  \
# 0                    0.1370
# 1                    0.0303
# 2                    0.0244
# 3                    0.1440
# 4                    0.1440
#
#    Écotoxicité pour écosystèmes aquatiques d'eau douce  Utilisation du sol  \
# 0                                               70.2                 106.0
# 1                                               11.0                  67.7
# 2                                               30.8                 116.0
# 3                                               57.9                  26.7
# 4                                               57.9                  26.7
#
#    Épuisement des ressources eau  Épuisement des ressources énergétiques  \
# 0                          3.380                                   700.0
# 1                          2.470                                    24.4
# 2                          0.422                                    22.4
# 3                          4.830                                   396.0
# 4                          4.830                                   396.0
#
#    Épuisement des ressources minéraux  \
# 0                            0.000051
# 1                            0.000006
# 2                            0.000004
# 3                            0.000079
# 4                            0.000079
#
#    Changement climatique - émissions biogéniques  \
# 0                                         0.1040
# 1                                         0.0336
# 2                                         0.0252
# 3                                         0.0401
# 4                                         0.0401
#
#    Changement climatique - émissions fossiles  \
# 0                                       7.460
# 1                                       1.020
# 2                                       0.965
# 3                                      11.700
# 4                                      11.700
#
#    Changement climatique - émissions liées au changement d'affectation des sols
# 0                                            0.02120
# 1                                           -0.10800
# 2                                            0.18400
# 3                                            0.00655
# 4                                            0.00655
#
# [5 rows x 32 columns]

# %%
df.shape
# Out:
# (14956, 32)

# %% [markdown]
# ## Train Set
# En machine learning, on divise les données en deux parties principales :
# -Train Set (jeu d'entraînement)
# -Test Set (jeu de test)
#
# Cette séparation est essentielle pour évaluer la performance réelle du modèle.
# Le Train Set est utilisé pour entraîner le modèle, c’est-à-dire lui faire apprendre les relations entre les variables d’entrée et la variable cible.
# Le Test Set, lui, n’est jamais montré au modèle pendant l’entraînement. Il sert à simuler de nouvelles données jamais vues, comme dans un cas réel d’utilisation.
# Cela permet de vérifier si le modèle généralise bien, c’est-à-dire s’il est capable de faire de bonnes prédictions sur des données inconnues et pas juste de “mémoriser” l’entraînement.

# %%
main_target = 'Changement climatique'

def setup(target):
    #Définir la variable cible
    y = df[target]

    #Supprimer la cible de X
    X = df.drop(target, axis=1)

    # Garder uniquement les lignes sans NaN dans y
    mask = y.notna()
    y = y.loc[mask]
    X = df.loc[mask].drop(target, axis=1)

    X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=0, test_size=0.2)
    return X_train, X_test, y_train, y_test
    
X_train, X_test, y_train, y_test = setup(main_target)

# %% [markdown]
# ## Pipeline de transformation
# Les données non numériques ne peuvent pas être traitées directement par notre modèle, il faut donc les transformer. Plusieurs solutions existent, comme l'encodage par label (non adapté aux modèles linéaires) ou l'encodage one-hot, qui est préférable ici.
# Il faut également décider comment gérer les données manquantes : supprimer les lignes concernées ou les remplacer par une valeur par défaut.

# %%
# Sélecteurs automatiques
numerical_features = make_column_selector(dtype_include=np.number)
categorical_features = make_column_selector(dtype_exclude=np.number)

# Pipelines
numerical_pipeline = make_pipeline(
    SimpleImputer(strategy="mean"),  # remplace NaN par moyenne
    StandardScaler() # uniformise l’échelle des données
)

categorical_pipeline = make_pipeline(
    SimpleImputer(strategy='constant', fill_value='unknown'),  # remplace NaN par 'unknown'
    OneHotEncoder(handle_unknown="ignore")
)


def regressor(model_type, num_pip=numerical_pipeline, cat_pip=categorical_pipeline):
    # Préprocesseur complet
    preprocessor = make_column_transformer(
        (num_pip, numerical_features),
        (cat_pip, categorical_features)
    )

    model = Pipeline([
        ('preprocessing', preprocessor),
        ('regressor', model_type)
    ])
    return model

# %% [markdown]
# ## Fonction d'évaluation

# %% [markdown]
# Pour juger un modèle de régression, on utilise plusieurs tests et visualisations qui permettent d’évaluer à la fois son apprentissage et sa capacité à prédire correctement.
#
# La courbe d’apprentissage sert à observer comment la performance du modèle évolue lorsque la quantité de données d’entraînement augmente. Elle montre typiquement deux courbes : la performance sur les données utilisées pour entraîner le modèle, et la performance sur des données de validation. Cela permet de détecter si le modèle souffre de sous-apprentissage (les deux courbes sont basses) ou de sur-apprentissage (écart important entre les deux courbes). Un bon modèle est celui où les courbes convergent vers un niveau élevé, indiquant que le modèle généralise bien.
#
# Les métriques comme l’erreur quadratique moyenne (MSE) ou l’erreur absolue moyenne (MAE) quantifient l’écart moyen entre les prédictions du modèle et les valeurs réelles sur un jeu de test indépendant. Elles permettent d’avoir une mesure précise de la qualité des prédictions. Le coefficient de détermination R2 donne également une idée de la proportion de variance expliquée par le modèle, donc de sa pertinence.
# -La MSE calcule la moyenne des carrés des écarts. En élevant au carré chaque différence, elle pénalise fortement les erreurs importantes, ce qui rend cette métrique particulièrement sensible aux valeurs aberrantes. Cela signifie qu’une grosse erreur aura un impact beaucoup plus important sur la MSE, ce qui peut être utile si vous voulez que le modèle évite à tout prix les grosses erreurs.
# -La MAE, quant à elle, calcule la moyenne des valeurs absolues des écarts, ce qui lui donne une interprétation plus intuitive : c’est l’écart moyen en valeur absolue entre les prédictions et les observations. Elle est moins sensible aux erreurs extrêmes car elle ne les amplifie pas par un carré, ce qui la rend plus robuste face aux valeurs aberrantes.
# En résumé, la MSE met plus l’accent sur les grandes erreurs tandis que la MAE offre une mesure plus directe de l’erreur moyenne sans accentuation particulière. Le choix entre les deux dépend de ce que vous souhaitez privilégier dans votre modèle.
#
# En combinant ces éléments, on peut vérifier que le modèle apprend correctement, qu’il n’est ni trop simple ni trop complexe, et qu’il fait des prédictions fiables. Ces tests doivent toujours être adaptés selon les objectifs et contraintes du projet.

# %%
def train_evaluation(model):
    model.fit(X_train, y_train)
    y_pred = model.predict(X_test)

    # Afficher des métriques adaptées à la régression
    print("MSE:", mean_squared_error(y_test, y_pred))
    print("MAE:", mean_absolute_error(y_test, y_pred))
    print("R2 score:", r2_score(y_test, y_pred))

    # Learning curve (attention scoring doit être adapté)
    N, train_score, val_score = learning_curve(
        model, X_train, y_train,
        cv=4, scoring='r2', train_sizes=np.linspace(0.1, 1, 10)
    )
    plt.figure(figsize=(12, 8))
    plt.plot(N, train_score.mean(axis=1), label='train score')
    plt.plot(N, val_score.mean(axis=1), label='validation score')
    plt.legend()
    plt.show()

# %%
def result_evaluation(model):
    y_pred = model.predict(X_test)
    
    # 1. Valeurs réelles vs prédites
    plt.figure(figsize=(12, 5))

    plt.subplot(1, 2, 1)
    plt.plot(y_test.values, label='Valeurs réelles', marker='o')
    plt.plot(y_pred, label='Valeurs prédites', marker='x')
    plt.title("Valeurs réelles vs. prédites")
    plt.xlabel("Index")
    plt.ylabel("Changement climatique (kg CO₂)")
    plt.legend()

    # 2. Erreur absolue
    plt.subplot(1, 2, 2)
    errors = np.abs(y_test.values - y_pred)
    plt.plot(errors, color='red', marker='.', label="Erreur absolue")
    plt.title("Erreur de prédiction")
    plt.xlabel("Index")
    plt.ylabel("Erreur absolue (kg CO₂)")
    plt.legend()

    plt.tight_layout()
    plt.show()

# %%
model = regressor(LinearRegression())
train_evaluation(model)
result_evaluation(model)
# Out:
# MSE: 0.004375897683299186
# MAE: 0.03361960503444749
# R2 score: 0.9999466064190032

# %% [markdown]
# ## Corrélation
# La corrélation est une mesure statistique qui indique dans quelle mesure deux variables sont liées entre elles. Elle varie entre :
# +1 : corrélation positive parfaite → quand une variable augmente, l'autre aussi.
# 0 : aucune corrélation → les deux variables n'ont pas de lien linéaire direct.
# -1 : corrélation négative parfaite → quand une variable augmente, l'autre diminue.

# %%
def cor_eval(display=True):
    numerical_cols = df.select_dtypes(include=np.number).columns.tolist()
    num_corr = df[numerical_cols].corr(method='pearson')[main_target].drop(main_target)

    if display:
        print("Corrélations Pearson avec " + main_target + " :\n")
        print(num_corr.sort_values(ascending=False))
        return

    return num_corr.to_dict()

cor_eval()
# Out:
# Corrélations Pearson avec Changement climatique :
#
# Score unique EF                                                                 0.953969
# Eutrophisation terrestre                                                        0.935170
# Acidification terrestre et eaux douces                                          0.930355
# Particules fines                                                                0.925290
# Changement climatique - émissions biogéniques                                   0.906216
# Effets toxicologiques sur la santé humaine : substances cancérogènes            0.893707
# Utilisation du sol                                                              0.865662
# Effets toxicologiques sur la santé humaine : substances non-cancérogènes        0.828495
# Changement climatique - émissions fossiles                                      0.800442
# Écotoxicité pour écosystèmes aquatiques d'eau douce                             0.667394
# Eutrophisation marine                                                           0.620342
# Épuisement des ressources énergétiques                                          0.509908
# Formation photochimique d'ozone                                                 0.445740
# Épuisement des ressources minéraux                                              0.401456
# Rayonnements ionisants                                                          0.264525
# Eutrophisation eaux douces                                                      0.243365
# Changement climatique - émissions liées au changement d'affectation des sols    0.220199
# DQR                                                                             0.175634
# Épuisement des ressources eau                                                   0.088534
# Code CIQUAL                                                                     0.030563
# code saison                                                                     0.022092
# code avion                                                                      0.012594
# Appauvrissement de la couche d'ozone                                            0.008781
# Name: Changement climatique, dtype: float64

# %% [markdown]
# ## Feature Engineering
# Après avoir examiné les corrélations entre les différentes variables et notre variable cible, nous sommes en mesure d’identifier celles qui ont un impact significatif sur le modèle. En conservant les variables les plus pertinentes et en supprimant celles qui présentent une corrélation faible ou négligeable, nous améliorons la qualité des données utilisées. Ce travail de sélection, de transformation ou de création de nouvelles variables à partir des données existantes s’appelle le Feature Engineering.

# %%
def drop_columns(threshold, upper=False):
    # Récupérer toutes les corrélations/scores (num + catégoriel)
    scores = cor_eval(display=False)

    if upper:
        # Supprimer colonnes avec score >= threshold
        cols_to_drop = [col for col, score in scores.items() if score >= threshold]
    else:
        # Supprimer colonnes avec score < threshold
        cols_to_drop = [col for col, score in scores.items() if score < threshold]

    dfClean = df.drop(columns=cols_to_drop, errors='ignore')

    print(f"Colonnes supprimées ({'>= ' if upper else '< '} {threshold}): {cols_to_drop}")

    return dfClean

df = drop_columns(0.10)  # supprime colonnes avec score < 0.20
# Out:
# Colonnes supprimées (<  0.1): ['Code CIQUAL', 'code saison', 'code avion', "Appauvrissement de la couche d'ozone", 'Épuisement des ressources eau']

# %%
X_train, X_test, y_train, y_test = setup(main_target)

# %%
model = regressor(LinearRegression())
train_evaluation(model)
result_evaluation(model)
# Out:
# MSE: 0.008549662476827296
# MAE: 0.036420776677006626
# R2 score: 0.9998956792116749

# %% [markdown]
# On constate qu’après la suppression de certaines variables peu corrélées à la cible, le modèle parvient tout de même à prédire avec une grande précision le niveau de changement climatique. Cela montre que toutes les variables initiales ne sont pas nécessaires à la performance du modèle. Le choix des caractéristiques à conserver ou à éliminer dépendra donc fortement de vos objectifs métier et des contraintes définies dans votre cahier des charges (ex. : interprétabilité, temps de calcul, simplicité du modèle, etc.).

# %% [markdown]
# # Cas plus compliqué

# %% [markdown]
# Dans notre cas précédent, la forte corrélation entre le score EF et le changement climatique a permis d’obtenir très rapidement des résultats satisfaisants lors des premiers tests. Ici, nous allons modifier un peu nos données en supprimant les variables trop corrélées afin de relever un peu le défi. Cela nous permettra d’optimiser les variables restantes et de tester différents modèles pour identifier celui qui est le plus performant.

# %%
df = pd.read_csv("agribalyse_data.csv", sep=",")
cor_eval()
# Out:
# Corrélations Pearson avec Changement climatique :
#
# Score unique EF                                                                 0.953969
# Eutrophisation terrestre                                                        0.935170
# Acidification terrestre et eaux douces                                          0.930355
# Particules fines                                                                0.925290
# Changement climatique - émissions biogéniques                                   0.906216
# Effets toxicologiques sur la santé humaine : substances cancérogènes            0.893707
# Utilisation du sol                                                              0.865662
# Effets toxicologiques sur la santé humaine : substances non-cancérogènes        0.828495
# Changement climatique - émissions fossiles                                      0.800442
# Écotoxicité pour écosystèmes aquatiques d'eau douce                             0.667394
# Eutrophisation marine                                                           0.620342
# Épuisement des ressources énergétiques                                          0.509908
# Formation photochimique d'ozone                                                 0.445740
# Épuisement des ressources minéraux                                              0.401456
# Rayonnements ionisants                                                          0.264525
# Eutrophisation eaux douces                                                      0.243365
# Changement climatique - émissions liées au changement d'affectation des sols    0.220199
# DQR                                                                             0.175634
# Épuisement des ressources eau                                                   0.088534
# Code CIQUAL                                                                     0.030563
# code saison                                                                     0.022092
# code avion                                                                      0.012594
# Appauvrissement de la couche d'ozone                                            0.008781
# Name: Changement climatique, dtype: float64

# %%
max_threshold = 70 #en %
df = drop_columns(max_threshold / 100, True) #Supprimons toutes les corrélations supérieures au seuil
# Out:
# Colonnes supprimées (>=  0.7): ['Score unique EF', 'Particules fines', 'Effets toxicologiques sur la santé humaine\xa0: substances non-cancérogènes', 'Effets toxicologiques sur la santé humaine\xa0: substances cancérogènes', 'Acidification terrestre et eaux douces', 'Eutrophisation terrestre', 'Utilisation du sol', 'Changement climatique - émissions biogéniques', 'Changement climatique - émissions fossiles']

# %%
X_train, X_test, y_train, y_test = setup(main_target)

# %%
model = regressor(LinearRegression())
train_evaluation(model)
result_evaluation(model)
# Out:
# MSE: 18.563762755595743
# MAE: 2.4240917654596066
# R2 score: 0.7734897289579046

# %% [markdown]
# On constate tout de suite des résultats moins performants et des taux d’erreurs plus élevés. C’est normal, car maintenant, il s’agira pour nous de les réduire.

# %% [markdown]
# ## Test de plusieurs algorithmes
# Nous allons maintenant produire des tests avec différents algorithmes de régression afin de voir le plus performant avec ces données

# %%
def multi_evaluation(model_types):
    for name, model_class in model_types.items():
        print(f"Modèle de type {name}")
        model = regressor(model_class())
        train_evaluation(model)
        result_evaluation(model)

model_types_dico = {
    "LinearRegression": LinearRegression,
    "Ridge": Ridge,
    "Lasso": Lasso,
    "ElasticNet": ElasticNet
}

multi_evaluation(model_types_dico)
# Out:
# Modèle de type LinearRegression
# MSE: 18.563762755595743
# MAE: 2.4240917654596066
# R2 score: 0.7734897289579046
# Modèle de type Ridge
# MSE: 18.611802272725132
# MAE: 2.422489937197707
# R2 score: 0.7729035630933129
# Modèle de type Lasso
# MSE: 34.073557337378965
# MAE: 3.0123965437079874
# R2 score: 0.5842431941481465
# Modèle de type ElasticNet
# MSE: 36.09080287844089
# MAE: 3.0139416266380463
# R2 score: 0.5596292815335469

# %% [markdown]
# ## Analyse résultats

# %% [markdown]
# On observe que les modèles LinearRegression et Ridge obtiennent des performances très proches, avec des erreurs relativement faibles (MSE autour de 18.6 et MAE proche de 2.4) et un coefficient de détermination R2 d’environ 0.77, indiquant que ces modèles expliquent bien la majorité de la variance des données. En revanche, les modèles Lasso et ElasticNet affichent des performances nettement inférieures, avec des erreurs plus élevées et un R2 bien plus bas, ce qui suggère une moins bonne capacité à modéliser la relation entre les variables. Cela peut être dû à une régularisation trop forte ou à une sélection excessive de variables qui réduit la complexité du modèle au détriment de la précision. Ces résultats montrent que pour ce jeu de données, des modèles linéaires simples ou avec une régularisation légère sont plus adaptés, tandis qu’une régularisation plus agressive semble pénaliser la qualité des prédictions.
#
# Résumé des résultats :
#
# Modèle de type LinearRegression
# MSE: 18.563762755595743
# MAE: 2.4240917654596066
# R2 score: 0.7734897289579046
#
# Modèle de type Ridge
# MSE: 18.611802272725132
# MAE: 2.422489937197707
# R2 score: 0.7729035630933129
#
# Modèle de type Lasso
# MSE: 34.073557337378965
# MAE: 3.0123965437079874
# R2 score: 0.5842431941481465
#
# Modèle de type ElasticNet
# MSE: 36.09080287844089
# MAE: 3.0139416266380463
# R2 score: 0.5596292815335469

# %% [markdown]
# Voir que Lasso et ElasticNet sont moins performants n’est pas étonnant. Ce sont des algorithmes plus optimisés lorsque le nombre de features à analyser est réduit. Ils auraient sans doute été beaucoup plus performants si on avait conservé uniquement les features avec une corrélation supérieure à 80 %, par exemple.

# %% [markdown]
# ## Pistes d'améliorations
# Pour améliorer les performances de ces modèles linéaires, plusieurs pistes peuvent être explorées. Tout d’abord, il est possible d’ajuster les hyperparamètres liés à la régularisation.
#
# Par ailleurs, il est important de considérer la qualité des données en entrée. Travailler sur le pipeline de traitement, notamment sur les méthodes de remplacement des valeurs manquantes, peut grandement influencer les résultats. Selon la nature des données, différentes stratégies d’imputation (moyenne, médiane, interpolation, ou méthodes plus avancées comme KNN ou modèles prédictifs) peuvent être testées pour optimiser la préparation des données. Enfin, on pourra toujours continuer à jouer sur la sélection, la transformation ou la création de nouvelles variables (feature engineering).

# %% [markdown]
# ### Changement dans les pipelines

# %% [markdown]
# Après plusieurs tests en modifiant les valeurs, les résultats restent les mêmes. Le fichier CSV contient très peu de données manquantes (NaN). Il serait intéressant de faire des tests avec des données comportant davantage de valeurs manquantes pour observer la réaction des modèles.

# %% [markdown]
# ### LinearRegression
# Modèle de base sans régularisation, donc peu d’hyperparamètres :
# -fit_intercept (ajouter ou non un biais)

# %%
model = regressor(LinearRegression(fit_intercept=False)) # True par défaut
train_evaluation(model)
result_evaluation(model)
# Out:
# MSE: 18.521878416505594
# MAE: 2.42103954968333
# R2 score: 0.7740007909190294

# %% [markdown]
# Les résultats précédents étaient plus performants sauf pour la MAE
# Précédent / Nouveaux
# MSE: 18.563762755595743 / 19.7164650883137
# MAE: 2.4240917654596066 / 2.387298130205095
# R2 score: 0.7734897289579046 / 0.7594247507930605

# %% [markdown]
# Je ne vais pas tester tous les modèles, mais cela donne une idée des possibilités d'améliorations

# %% [markdown]
# ### Ridge (régression linéaire avec régularisation L2) :
# alpha : force de la régularisation (plus alpha est grand, plus le modèle est régularisé, ce qui peut réduire l’overfitting mais augmenter le biais).
# -solver : méthode d’optimisation.
# -max_iter et tol : nombre max d’itérations et tolérance pour la convergence.

# %% [markdown]
# ### Lasso (régression avec régularisation L1) :
# -alpha : même rôle que dans Ridge, contrôle la force de la pénalisation.
# -max_iter, tol : pour la convergence.
# -positive : contraindre les coefficients à être positifs (optionnel).

# %% [markdown]
# ### ElasticNet (combinaison de L1 et L2) :
# -alpha : intensité globale de régularisation.
# -l1_ratio : proportion entre L1 (lasso) et L2 (ridge) (0 = Ridge pur, 1 = Lasso pur).
# -max_iter, tol : convergence.

# %% [markdown]
# ## Conclusion

# %% [markdown]
# En conclusion, les performances d’un modèle dépendent surtout des données et de leurs corrélations, ainsi que de leur qualité, notamment la présence ou non de valeurs manquantes et la manière dont elles sont traitées. Il est également important de choisir un modèle adapté au contexte et aux besoins, puis d’ajuster ses paramètres pour optimiser les résultats.

# %% [markdown]
# # Exportation d'un modèle

# %% [markdown]
# Je vais exporter mon modèle de régression linéaire entraîné sur les features dont la corrélation est comprise entre 20 % et 90 %, en imaginant un contexte où je ne dispose pas des features très fortement corrélées. Cela permet de réduire le nombre de variables à analyser et d’éviter les redondances.
#
# Dans un vrai projet, j’aurais conservé le modèle très performant utilisant les données avec une corrélation supérieure à 90 %, tout en optimisant les autres features avant de procéder à l’exportation.

# %%
#entrainement du modèle
df = pd.read_csv("agribalyse_data.csv", sep=",")

max_threshold = 90 #en %
min_threshold = 20
df = drop_columns(max_threshold / 100, True)
df = drop_columns(min_threshold / 100)

X_train, X_test, y_train, y_test = setup(main_target)

model = regressor(LinearRegression())
train_evaluation(model)
result_evaluation(model)
# Out:
# Colonnes supprimées (>=  0.9): ['Score unique EF', 'Particules fines', 'Acidification terrestre et eaux douces', 'Eutrophisation terrestre', 'Changement climatique - émissions biogéniques']
# Colonnes supprimées (<  0.2): ['Code CIQUAL', 'code saison', 'code avion', 'DQR', "Appauvrissement de la couche d'ozone", 'Épuisement des ressources eau']
# MSE: 3.953108448887692
# MAE: 1.1522694772366224
# R2 score: 0.9517651847847259

# %%
#Test sur des produits solos
test_df = df[df["Nom du Produit en Français"] == "Pizza, sauce garniture pour"].copy()
X_single = test_df.drop(columns=[main_target])

# Prédiction
print("Prédiction :", model.predict(X_single)[0])
test_df[main_target].values[0]
# Out:
# Prédiction : 1.1089203629991138
# np.float64(0.94)

# %%
test_df = df[df["Nom du Produit en Français"] == "Agar (algue), cru"].copy()
X_single = test_df.drop(columns=[main_target])

# Prédiction
print("Prédiction :", model.predict(X_single)[0])
test_df[main_target].values[0]
# Out:
# Prédiction : 11.800509669189074
# np.float64(11.8)

# %% [markdown]
# ## Script d'exportation

# %%
import pickle

# Export du modèle avec pickle
with open("linear_regression_model.pkl", "wb") as f:
    pickle.dump(model, f)
print("Modèle exporté avec succès.")
# Out:
# Modèle exporté avec succès.

# %%
from IPython.display import display, Markdown

cols = X_train.columns.tolist()
display(Markdown("### Features gardées :"))
for col in cols:
    display(Markdown(f"- {col}"))
# Out:
# ### Features gardées :
# - Code AGB
# - Groupe d'aliment
# - Sous-groupe d'aliment
# - Nom du Produit en Français
# - LCI Name
# - Livraison
# - Approche emballage
# - Préparation
# - Rayonnements ionisants
# - Formation photochimique d'ozone
# - Effets toxicologiques sur la santé humaine : substances non-cancérogènes
# - Effets toxicologiques sur la santé humaine : substances cancérogènes
# - Eutrophisation eaux douces
# - Eutrophisation marine
# - Écotoxicité pour écosystèmes aquatiques d'eau douce
# - Utilisation du sol
# - Épuisement des ressources énergétiques
# - Épuisement des ressources minéraux
# - Changement climatique - émissions fossiles
# - Changement climatique - émissions liées au changement d'affectation des sols

# %%
display(Markdown("### Cible :"))
print(y_train.name)
# Out:
# ### Cible :
# Changement climatique
